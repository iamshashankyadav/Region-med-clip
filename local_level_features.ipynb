# %%
# !pip install ultralytics opencv-python numpy pandas
# Out:
# Requirement already satisfied: ultralytics in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (8.3.193)
# Requirement already satisfied: opencv-python in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (1.23.5)
# Requirement already satisfied: pandas in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (2.2.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (3.10.5)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (0.17.2)
# Requirement already satisfied: psutil in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: polars in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (1.33.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from ultralytics) (2.0.17)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: networkx in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\raunak\anaconda3\envs\py310\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %%
import os
import cv2
import numpy as np
import pandas as pd
from ultralytics import YOLO
from tqdm import tqdm
import random

# ---- Config ----
IMG_DIR = "HAM10000_images_final"
CROP_DIR = "crops"
os.makedirs(CROP_DIR, exist_ok=True)
OUTPUT_CSV = "local_labels.csv"

# lightweight YOLO model (you can use yolov8n.pt for speed)
model = YOLO("yolov8n.pt")

# %%
# simple mappings
colors = ["reddish", "brownish", "light", "dark", "pale", "pinkish"]
textures = ["smooth", "rough", "irregular"]
borders = ["well-defined", "blurred", "uneven"]
positions = ["upper left", "upper center", "upper right",
              "center left", "center", "center right",
              "lower left", "lower center", "lower right"]

# templates for captions
templates = [
    "A {color} lesion with {texture} texture located at the {position}.",
    "An area of {color} skin showing {texture} pattern at the {position}.",
    "A {color} patch with {border} borders seen at the {position}.",
    "An {texture} lesion with {color} pigmentation at the {position}.",
    "A {color} lesion showing {border} edges at the {position}."
]

records = []

# ---- Helper Functions ----
def get_position(bbox, img_shape):
    x1, y1, x2, y2 = bbox
    cx = (x1 + x2) / 2
    cy = (y1 + y2) / 2
    h, w = img_shape[:2]

    row = "upper" if cy < h/3 else "center" if cy < 2*h/3 else "lower"
    col = "left" if cx < w/3 else "center" if cx < 2*w/3 else "right"
    return f"{row} {col}"

def get_color_name(crop):
    mean_bgr = np.mean(crop, axis=(0,1))
    avg = np.mean(mean_bgr)
    if avg < 60: return "dark"
    elif avg < 120: return "brownish"
    elif avg < 180: return "light"
    else: return "pale"

# %%
# ---- Run Inference ----
for img_file in tqdm(os.listdir(IMG_DIR)):
    if not img_file.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    img_path = os.path.join(IMG_DIR, img_file)
    img = cv2.imread(img_path)
    if img is None:
        continue

    results = model(img, verbose=False)[0]

    for i, box in enumerate(results.boxes.xyxy.cpu().numpy()):
        x1, y1, x2, y2 = map(int, box)
        conf = float(results.boxes.conf[i])
        cls = int(results.boxes.cls[i]) if results.boxes.cls is not None else -1

        # crop and save
        crop = img[y1:y2, x1:x2]
        crop_path = os.path.join(CROP_DIR, f"{os.path.splitext(img_file)[0]}_{i}.jpg")
        cv2.imwrite(crop_path, crop)

        # generate label
        label = random.choice(templates).format(
            color=get_color_name(crop),
            texture=random.choice(textures),
            border=random.choice(borders),
            position=get_position((x1,y1,x2,y2), img.shape)
        )

        records.append({
            "image_id": img_file,
            "lesion_id": i,
            "bbox": [x1, y1, x2, y2],
            "conf": round(conf, 3),
            "class": cls,
            "crop_path": crop_path,
            "local_label": label
        })
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 472/472 [02:10<00:00,  3.62it/s]

# %%
# save results
pd.DataFrame(records).to_csv(OUTPUT_CSV, index=False)
print(f"\n✅ Done! Saved {len(records)} lesion labels to {OUTPUT_CSV}")
# Out:
# ✅ Done! Saved 73 lesion labels to local_labels.csv

# %%
import os
import random
import torch
import pandas as pd
from ultralytics import YOLO
from PIL import Image




# Load YOLO model (lightweight)
# even COCO-pretrained works fine just to get bounding boxes
model = YOLO("yolov8n.pt")

# ==========================
# TEMPLATE SETTINGS (you’ll fill these later)
# ==========================
# Leave empty for now — you’ll manually inject your list later
local_label_templates = [
    "An irregular pigmented lesion located at the {position} of the image.",
    "A small {color} lesion appearing near the {position}.",
    "A {texture} and {color} spot visible at the {position}.",
    "Lesion with {texture} texture located centrally.",
    "A {size} lesion found on the {position} side of the image.",
    "The {color} lesion with {texture} surface lies toward the {position}.",
    "A {color} patch showing {texture} edges in the {position}.",
    "Lesion area of {size} and {texture} type, seen near {position}.",
    "A slightly {color} lesion detected at the {position}.",
    "A {texture}, {color} mark can be seen toward the {position}.",
    "Pigmented {texture} lesion visible at the {position}.",
    "A small {color} circular lesion lies at the {position}.",
    "A {texture} lesion occupying the {position} region.",
    "Visible {color} lesion of {size} size at the {position}.",
    "A lesion of {color} pigmentation located near the {position}.",
    "This image contains a {color} lesion in the {position} with {texture} texture.",
    "The lesion is {texture} and {color}, centered toward the {position}.",
    "Observed {color} and {texture} lesion occupying {position} of the frame.",
    "Localized {color} lesion with irregular boundary on the {position}.",
    "An evident {color} lesion placed around the {position}.",
    "A {texture} mark visible at the {position} area.",
    "Lesion of {size} size appears in the {position}.",
    "Irregular {color} region situated at the {position}.",
    "A {texture} lesion with {color} pigmentation at the {position}.",
    "Pigmentation in {color} tone concentrated at the {position}.",
    "Single lesion detected near the {position}, showing {texture} pattern."
]


# Supporting lists for random choice
colors = ["reddish", "brown", "light brown", "dark", "blackish", "pinkish", "tan", "flesh-colored"]
textures = ["smooth", "rough", "irregular", "scaly", "flat", "elevated", "granular"]
positions = ["top-left", "top-right", "bottom-left", "bottom-right", "center"]
sizes = ["small", "medium", "large"]

# ==========================
# UTILS
# ==========================
def fallback_crop(img: Image.Image):
    """Return central 60% region if YOLO fails."""
    w, h = img.size
    left, top = int(0.2*w), int(0.2*h)
    right, bottom = int(0.8*w), int(0.8*h)
    return (left, top, right, bottom)

# %%
import cv2
import numpy as np
import pandas as pd
from pathlib import Path

# === CONFIG ===
IMAGES_DIR = Path("HAM10000_images_final/")             # folder containing original images
OUTPUT_DIR = Path("lesion_crops/")       # folder to save cropped lesion images
OUTPUT_DIR.mkdir(exist_ok=True)
OUTPUT_CSV = "local_labels_true.csv"

# === HELPER FUNCTIONS ===
def get_color_name(rgb):
    """Roughly classify lesion color based on mean RGB"""
    r, g, b = rgb
    if np.mean(rgb) < 60:
        return "dark"
    if r > g and r > b:
        return "reddish"
    if g > r and g > b:
        return "greenish"
    if b > r and b > g:
        return "bluish"
    if abs(r - g) < 20 and abs(g - b) < 20:
        return "grayish"
    if r > 120 and g > 100 and b < 80:
        return "brownish"
    return "light-colored"

def get_position_label(cx, cy, shape):
    """Return position label (top-left, center, bottom-right, etc.)"""
    h, w = shape[:2]
    x_zone = "left" if cx < w/3 else "right" if cx > 2*w/3 else "center"
    y_zone = "top" if cy < h/3 else "bottom" if cy > 2*h/3 else "middle"
    return f"{y_zone}-{x_zone}"

def find_lesion_bbox(image):
    """Detect main lesion using simple threshold + contour analysis"""
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # Adaptive threshold or Otsu for flexible lighting
    _, mask = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if not contours:
        return None

    lesion_contour = max(contours, key=cv2.contourArea)
    x, y, w, h = cv2.boundingRect(lesion_contour)
    return x, y, w, h

# %%
# === MAIN PROCESS ===
rows = []
image_paths = list(IMAGES_DIR.glob("*.jpg")) + list(IMAGES_DIR.glob("*.png"))

for img_path in image_paths:
    try:
        img = cv2.imread(str(img_path))
        if img is None:
            print(f"⚠️ Skipped unreadable file: {img_path.name}")
            continue

        result = find_lesion_bbox(img)
        if result is None:
            print(f"❌ No lesion detected for: {img_path.name}")
            continue

        x, y, w, h = result

        # Ensure reasonable crop size
        if w < 10 or h < 10:
            print(f"⚠️ Too small lesion region in {img_path.name}")
            continue

        lesion_crop = img[y:y+h, x:x+w]
        crop_path = OUTPUT_DIR / f"{img_path.stem}_lesion.jpg"
        cv2.imwrite(str(crop_path), lesion_crop)

        # Mean color & position label
        mean_color = lesion_crop.mean(axis=(0, 1)).astype(int)
        color_name = get_color_name(mean_color)
        cx, cy = x + w // 2, y + h // 2
        pos_label = get_position_label(cx, cy, img.shape)

        desc = f"A {color_name} lesion located at the {pos_label} of the image."

        rows.append({
            "image_id": img_path.stem,
            "x_min": x,
            "y_min": y,
            "x_max": x + w,
            "y_max": y + h,
            "color": color_name,
            "position": pos_label,
            "description": desc,
            "crop_path": str(crop_path)
        })

        print(f"✅ Processed: {img_path.name} -> {color_name}, {pos_label}")

    except Exception as e:
        print(f"⚠️ Error processing {img_path.name}: {e}")

# === SAVE CSV ===
if rows:
    df = pd.DataFrame(rows)
    df.to_csv(OUTPUT_CSV, index=False)
    print(f"\n✅ Done! Saved {len(df)} lesion crops and labels to {OUTPUT_CSV}")
else:
    print("\n⚠️ No valid lesions found. Please check the input images folder.")
# Out:
# ✅ Processed: ISIC_0024334.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024386.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024392.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024398.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024406.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024445.jpg -> bluish, top-center
# ✅ Processed: ISIC_0024450.jpg -> bluish, bottom-right
# ✅ Processed: ISIC_0024452.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024455.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024460.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024488.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024521.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024538.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024542.jpg -> bluish, top-center
# ✅ Processed: ISIC_0024544.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024556.jpg -> bluish, top-center
# ✅ Processed: ISIC_0024570.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024572.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024580.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024602.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0024614.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024621.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024633.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024635.jpg -> bluish, top-right
# ✅ Processed: ISIC_0024678.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0024699.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024701.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024719.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024726.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024736.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024751.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024768.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024771.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024802.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024819.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024831.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0024843.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024867.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024869.jpg -> bluish, bottom-left
# ✅ Processed: ISIC_0024884.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024887.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024890.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024893.jpg -> dark, middle-left
# ✅ Processed: ISIC_0024900.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024909.jpg -> bluish, bottom-left
# ✅ Processed: ISIC_0024929.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024953.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024954.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024957.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0024968.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024975.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024985.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0024997.jpg -> bluish, top-right
# ✅ Processed: ISIC_0025007.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025015.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025028.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025039.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025045.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025053.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025063.jpg -> bluish, bottom-left
# ✅ Processed: ISIC_0025072.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025082.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025129.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0025136.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025140.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025147.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025175.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025190.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025204.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025212.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025233.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025236.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025239.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025267.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025280.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025282.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025289.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025298.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0025305.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025307.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025315.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0025328.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025344.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025351.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025364.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0025368.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0025371.jpg -> bluish, top-center
# ✅ Processed: ISIC_0025376.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0025383.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025389.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025426.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025433.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025443.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025448.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0025485.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0025521.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025522.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025531.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025535.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025543.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025558.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025564.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0025577.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0025585.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0025595.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025617.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025636.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025637.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025659.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025664.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025676.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025685.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025686.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025707.jpg -> bluish, top-left
# ✅ Processed: ISIC_0025722.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025728.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025747.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025751.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025765.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025783.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025795.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025796.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025802.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025814.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025819.jpg -> bluish, bottom-right
# ✅ Processed: ISIC_0025822.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025827.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025829.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025838.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025842.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025858.jpg -> bluish, top-center
# ✅ Processed: ISIC_0025866.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025880.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025886.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025952.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025966.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0025967.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0025975.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0026005.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026030.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026042.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026064.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026069.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026072.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0026079.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026084.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026115.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026150.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026168.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026172.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026173.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026182.jpg -> reddish, middle-left
# ✅ Processed: ISIC_0026183.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026186.jpg -> reddish, middle-right
# ✅ Processed: ISIC_0026200.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026203.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026214.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026219.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0026241.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026244.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026245.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026249.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0026260.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026261.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026264.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026278.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0026287.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026294.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026298.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0026302.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026311.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026319.jpg -> bluish, top-right
# ✅ Processed: ISIC_0026324.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026332.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026340.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026350.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026353.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026360.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026373.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026400.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0026403.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026404.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026415.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0026435.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026451.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026460.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026468.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026471.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026475.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026480.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026482.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026486.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026496.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0026515.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026527.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026541.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026557.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026568.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026573.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0026594.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026597.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026599.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026617.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026642.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026654.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0026666.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026674.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026683.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026690.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026723.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026739.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026744.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026755.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0026771.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026779.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026798.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026810.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026815.jpg -> bluish, top-center
# ✅ Processed: ISIC_0026873.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026876.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026924.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026927.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0026941.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026947.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0026963.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0026983.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0027000.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027003.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027015.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027019.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027025.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027048.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027050.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027059.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027070.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027078.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027083.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0027084.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027105.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027110.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027119.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027127.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0027134.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027139.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027158.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027170.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027177.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027210.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027211.jpg -> bluish, bottom-right
# ✅ Processed: ISIC_0027213.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027218.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027246.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027249.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0027295.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027297.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027299.jpg -> bluish, top-center
# ✅ Processed: ISIC_0027303.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027314.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027323.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027326.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027339.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027357.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027368.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027372.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027381.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027390.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027405.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027418.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027424.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027428.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0027440.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027448.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027452.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027459.jpg -> bluish, top-center
# ✅ Processed: ISIC_0027461.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027470.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027474.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027477.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027489.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027497.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027511.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027515.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027519.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027523.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027541.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027548.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027552.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027566.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027587.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027610.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027619.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027621.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0027634.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027635.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027636.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027637.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027644.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027647.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027652.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0027658.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027668.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027676.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027682.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027694.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027696.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027702.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027720.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027723.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027733.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027738.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0027739.jpg -> reddish, middle-left
# ✅ Processed: ISIC_0027748.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027760.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027761.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027775.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027781.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027799.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027808.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027809.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027817.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027825.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027828.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027829.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027833.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0027839.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027841.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027843.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027882.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027888.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0027891.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027894.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027913.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027919.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027921.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027923.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027940.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027957.jpg -> bluish, bottom-right
# ✅ Processed: ISIC_0027960.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027962.jpg -> bluish, top-center
# ✅ Processed: ISIC_0027968.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027971.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027977.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027978.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027982.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027988.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027991.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0027995.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028002.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0028006.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028024.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028028.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028030.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028036.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0028059.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028068.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028069.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0028083.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028090.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028094.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028095.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028096.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028099.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028142.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028143.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028146.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028189.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028223.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0028240.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028242.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028250.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028251.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028254.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028256.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028267.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028272.jpg -> bluish, bottom-right
# ✅ Processed: ISIC_0028279.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028284.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028290.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028309.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028313.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028317.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0028341.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028351.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028359.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028377.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028379.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028415.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028423.jpg -> bluish, top-center
# ✅ Processed: ISIC_0028427.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028442.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028445.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028459.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028462.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028465.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028475.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028480.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028481.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028484.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028502.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028521.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028523.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028526.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028544.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028551.jpg -> bluish, middle-right
# ✅ Processed: ISIC_0028580.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028597.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028611.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028620.jpg -> bluish, top-center
# ✅ Processed: ISIC_0028647.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028667.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028672.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028717.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028725.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028729.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028732.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0028740.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028745.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028760.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028762.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028778.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028782.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028788.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028798.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0028802.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028805.jpg -> bluish, top-center
# ✅ Processed: ISIC_0028807.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0028818.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028825.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028845.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028856.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028864.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028869.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028876.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0028894.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028902.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028910.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028936.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028945.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0028980.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028983.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0028985.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028989.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028991.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0028994.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029001.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029019.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029024.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029038.jpg -> bluish, bottom-left
# ✅ Processed: ISIC_0029046.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029084.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0029098.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0029107.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029114.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029115.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0029139.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029159.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029161.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029180.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029206.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029212.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029229.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029235.jpg -> bluish, bottom-left
# ✅ Processed: ISIC_0029239.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029245.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029248.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029251.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029253.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029262.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029263.jpg -> bluish, middle-left
# ✅ Processed: ISIC_0029283.jpg -> bluish, middle-center
# ✅ Processed: ISIC_0029284.jpg -> bluish, bottom-center
# ✅ Processed: ISIC_0029302.jpg -> bluish, middle-right
#
# ✅ Done! Saved 472 lesion crops and labels to local_labels_true.csv
